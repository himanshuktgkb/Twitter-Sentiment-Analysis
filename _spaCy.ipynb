# %%
# %%capture
pip install spacytextblob

# %%
import numpy as np
import pandas as pd
import spacy
from IPython.display import Markdown as md
from spacytextblob.spacytextblob import SpacyTextBlob
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/drive/MyDrive/MinorPData/Narendra Modi_data.csv')
df.head()
# Out:
#          Date             User  \
# 0  2022:10:19   QuestionsBotYT
# 1  2022:10:19       PaperDabba
# 2  2022:10:19   mnjworldcom123
# 3  2022:10:19  BravePedestrian
# 4  2022:10:19   NaMoPraveenKor
#
#                                                Tweet      Time
# 0                        Is Narendra Modi a toaster?  23:57:08
# 1  5G About To Bring Major Change, Will Revolutio...  23:56:38
# 2  Prime Minister Shri Narendra Modi along with H...  23:51:02
# 3  Bharat Mata has waited 5000 years for a true s...  23:40:58
# 4  How Narendra Modi’s game-changing Gati Shakti ...  23:34:25

# %%
rf = pd.read_csv('/content/drive/MyDrive/MinorPData/Rahul Gandhi_data.csv')
rf.head()
# Out:
#          Date             User  \
# 0  2022:10:19          MdIjran
# 1  2022:10:19  28bde43dae3c430
# 2  2022:10:19         SkAnzar5
# 3  2022:10:19    HariRamDamor2
# 4  2022:10:19     srinivas_das
#
#                                                Tweet      Time
# 0  @JaikyYadav16 इन विकल्पों में से और अभी के समय...  23:55:49
# 1  @ndtv Rahul Gandhi left congress in the mid ro...  23:53:30
# 2                         @JaikyYadav16 Rahul Gandhi  23:32:16
# 3             rahul Gandhi ji is real hero of india.  23:32:09
# 4  Rahul Gandhi is getting massive support in And...  23:21:18

# %%
df['Tweet']
# Out:
# 0                              Is Narendra Modi a toaster?
# 1        5G About To Bring Major Change, Will Revolutio...
# 2        Prime Minister Shri Narendra Modi along with H...
# 3        Bharat Mata has waited 5000 years for a true s...
# 4        How Narendra Modi’s game-changing Gati Shakti ...
#                                ...
# 69995    माननीय प्रधानमंत्री आदरणीय श्री Narendra Modi ...
# 69996    A specially customised Indian aircraft has rea...
# 69997    Watch: Prime Minister Narendra Modi's remarks ...
# 69998    8 Namibian cheetahs coming to India on PM Nare...
# 69999    Special plane lands in Namibia to get African ...
# Name: Tweet, Length: 70000, dtype: object

# %%
rf['Tweet']
# Out:
# 0        @JaikyYadav16 इन विकल्पों में से और अभी के समय...
# 1        @ndtv Rahul Gandhi left congress in the mid ro...
# 2                               @JaikyYadav16 Rahul Gandhi
# 3                   rahul Gandhi ji is real hero of india.
# 4        Rahul Gandhi is getting massive support in And...
#                                ...
# 69995    @BharatJSoni @dranupmodgil Ye chunawala 2 kodi...
# 69996    Even Rahul Gandhi's fiercest critics like myse...
# 69997    BHATTACHARJEE SHYAMAL: A " PSHYCOPATH " is Rah...
# 69998    @priyankac19 @MinistryWCD She is cooking 'hate...
# 69999              @INCIndia Rahul Gandhi video share karo
# Name: Tweet, Length: 70000, dtype: object

# %%
import pandas as pd
from spacy import load

# Load the spaCy model
nlp = load("en_core_web_sm")

# %%
# prompt: HOW can I insert a new attribute language who check the tweets language
df=df.iloc[:10000,:]
df['language'] = [nlp(tweet).lang for tweet in df['Tweet']]

# %%
df.head()
# Out:
#          Date             User  \
# 0  2022:10:19   QuestionsBotYT
# 1  2022:10:19       PaperDabba
# 2  2022:10:19   mnjworldcom123
# 3  2022:10:19  BravePedestrian
# 4  2022:10:19   NaMoPraveenKor
#
#                                                Tweet      Time  \
# 0                        Is Narendra Modi a toaster?  23:57:08
# 1  5G About To Bring Major Change, Will Revolutio...  23:56:38
# 2  Prime Minister Shri Narendra Modi along with H...  23:51:02
# 3  Bharat Mata has waited 5000 years for a true s...  23:40:58
# 4  How Narendra Modi’s game-changing Gati Shakti ...  23:34:25
#
#                language
# 0  14626626061804382878
# 1  14626626061804382878
# 2  14626626061804382878
# 3  14626626061804382878
# 4  14626626061804382878

# %%
import pandas as pd

# Assuming df is your DataFrame containing tweets with a column 'tweet_text'
# containing the text of the tweets

# Step 1: Filter tweets based on length
threshold = 100  # Choose your desired threshold
filtered_tweets = rf[rf['Tweet'].str.len() > threshold]

# Step 2: Randomly sample from the filtered tweets
num_tweets_to_select = 10000 # Choose the number of tweets you want to select
random_tweets = filtered_tweets.sample(n=num_tweets_to_select, random_state=42)  # You can set a random_state for reproducibility

# %%
random_tweets.head()
# Out:
#              Date             User  \
# 43427  2022:10:03   dharmendra3879
# 49614  2022:10:02  TheHansIndiaWeb
# 67581  2022:09:25         RRchaube
# 46952  2022:10:03   BSGOPINATH3434
# 6468   2022:10:17        Zoyaaa_z4
#
#                                                    Tweet      Time
# 43427  @digvijaya_28 @INCIndia @INCKarnataka @RahulGa...  18:24:07
# 49614  We pledge to unite India like Mahatma Gandhi u...  04:45:48
# 67581  @Rahul Gandhi ji Rajasthan mamle mein turant h...  14:38:44
# 46952  The Congress party family and Members need wom...  01:21:16
# 6468   This js really a an exciting things that Rahul...  12:51:54

# %%
len(random_tweets)
rf=random_tweets
rf.head()
# Out:
#              Date             User  \
# 43427  2022:10:03   dharmendra3879
# 49614  2022:10:02  TheHansIndiaWeb
# 67581  2022:09:25         RRchaube
# 46952  2022:10:03   BSGOPINATH3434
# 6468   2022:10:17        Zoyaaa_z4
#
#                                                    Tweet      Time
# 43427  @digvijaya_28 @INCIndia @INCKarnataka @RahulGa...  18:24:07
# 49614  We pledge to unite India like Mahatma Gandhi u...  04:45:48
# 67581  @Rahul Gandhi ji Rajasthan mamle mein turant h...  14:38:44
# 46952  The Congress party family and Members need wom...  01:21:16
# 6468   This js really a an exciting things that Rahul...  12:51:54

# %%
len(df)
# Out:
# 10000

# %%
# !pip install -q --upgrade tensorflow
# !pip install -q keras
# !pip install -q -U deep-translator
# !pip install -q langid
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 589.8/589.8 MB 1.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 74.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 70.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 65.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 55.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 26.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-keras 2.15.1 requires tensorflow<2.16,>=2.15, but you have tensorflow 2.16.1 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 1.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 9.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
# Next, we import preprocessing packages...
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from nltk.tokenize import word_tokenize
from deep_translator import GoogleTranslator
import langid

# %%
nlp = spacy.load('en_core_web_sm')
_=nlp.add_pipe('spacytextblob')

# %%
tweets=df.Tweet

# %%
tweets1=rf.Tweet

# %%
tweets=tweets.to_list()

# %%
tweets1=tweets1.to_list()

# %%
from tqdm import tqdm

# %%
headers=["Negative", "Neutral", "Positive"]

# %%
sentiment=[]
score=[]
for i in tqdm(range(0,len(tweets))):
    score.append(nlp(tweets[i])._.polarity) #The threshold was selected based on the distribution of the values. The distribuition can be seen below
    if score[i] >= 0.1:
        index = 2
        sentiment.append(headers[index])
    elif score[i] < 0:
        index = 0
        sentiment.append(headers[index])
    else:
        index=1
        sentiment.append(headers[index])
# Out:
# 100%|██████████| 10000/10000 [02:29<00:00, 66.74it/s]

# %%
sentiment1=[]
score1=[]
for i in tqdm(range(0,len(tweets1))):
    score1.append(nlp(tweets1[i])._.polarity)
    if score1[i] >= 0.1:
        index = 2
        sentiment1.append(headers[index])
    elif score1[i] < 0:
        index = 0
        sentiment1.append(headers[index])
    else:
        index=1
        sentiment1.append(headers[index])
# Out:
# 100%|██████████| 10000/10000 [02:32<00:00, 65.64it/s]

# %%
q25, q75 = np.percentile(score, [25, 75])
bin_width = 2 * (q75 - q25) * len(score) ** (-1/3)
bins = round((np.max(score) - np.min(score)) / bin_width)
plt.hist(score, density=True, bins=bins)  # density=False would make counts
plt.ylabel('Probability')
plt.xlabel('Data');

# %%
q25, q75 = np.percentile(score1, [25, 75])
bin_width = 2 * (q75 - q25) * len(score1) ** (-1/3)
bins = round((np.max(score1) - np.min(score1)) / bin_width)
plt.hist(score1, density=True, bins=bins)  # density=False would make counts
plt.ylabel('Probability')
plt.xlabel('Data');

# %%
np.unique(sentiment, return_counts=True)
# Out:
# (array(['Negative', 'Neutral', 'Positive'], dtype='<U8'),
#  array([ 871, 6196, 2933]))

# %%
np.unique(sentiment1, return_counts=True)
# Out:
# (array(['Negative', 'Neutral', 'Positive'], dtype='<U8'),
#  array([1379, 5396, 3225]))

# %%
data = pd.DataFrame(list(zip(tweets,score, sentiment)), columns = ['Tweet','polarity', 'sentiment'])

# %%
data1 = pd.DataFrame(list(zip(tweets1,score1, sentiment1)), columns = ['Tweet','polarity', 'sentiment'])

# %%
len(tweets)
# Out:
# 10000

# %%
len(sentiment)
# Out:
# 10000

# %%
data
# Out:
#                                                   Tweet  polarity sentiment
# 0                           Is Narendra Modi a toaster?    0.0000   Neutral
# 1     5G About To Bring Major Change, Will Revolutio...    0.0625   Neutral
# 2     Prime Minister Shri Narendra Modi along with H...    0.0250   Neutral
# 3     Bharat Mata has waited 5000 years for a true s...    0.3500  Positive
# 4     How Narendra Modi’s game-changing Gati Shakti ...    0.0000   Neutral
# ...                                                 ...       ...       ...
# 9995  Prime Minister Narendra Modi to inaugurate the...    0.0000   Neutral
# 9996  Union Cabinet chaired by PM Narendra Modi has ...    0.0000   Neutral
# 9997  In the run-up to the #Assembly polls, Prime Mi...    0.0000   Neutral
# 9998  PM Narendra Modi To Launch Rs 3,000 Crore Prad...    0.0000   Neutral
# 9999  अवन्तिकायां विहितावतारं, मुक्ति प्रदानाय च सज्...    0.0000   Neutral
#
# [10000 rows x 3 columns]

# %%
data1
# Out:
#                                                   Tweet  polarity sentiment
# 0     @digvijaya_28 @INCIndia @INCKarnataka @RahulGa...    0.0000   Neutral
# 1     We pledge to unite India like Mahatma Gandhi u...    0.0000   Neutral
# 2     @Rahul Gandhi ji Rajasthan mamle mein turant h...    0.0000   Neutral
# 3     The Congress party family and Members need wom...    0.5500  Positive
# 4     This js really a an exciting things that Rahul...    0.3000  Positive
# ...                                                 ...       ...       ...
# 9995  @Rishikagurjjar @SachinPilot Rg 1 hour sp /cp(...   -0.3125  Negative
# 9996  @srivatsayb You didn't understand the satire.\...    0.2500  Positive
# 9997  @VedYada91941780 Ye to mai bhi manta hun.........    0.0000   Neutral
# 9998  @CTRavi_BJP Congress have insulted Kannadigas ...    0.0000   Neutral
# 9999  Congress’ Bharat Jodo Yatra to enter Rahul Gan...    0.0000   Neutral
#
# [10000 rows x 3 columns]

# %%
ax = data.sentiment.value_counts().plot.barh()

ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '6196'), Text(0, 0, '2933'), Text(0, 0, '871')]

# %%
bx = data1.sentiment.value_counts().plot.barh()

bx.bar_label(bx.containers[0])
# Out:
# [Text(0, 0, '5396'), Text(0, 0, '3225'), Text(0, 0, '1379')]

# %%
import matplotlib.pyplot as plt

# Pie chart for ax
plt.figure(figsize=(10, 5))
ax_pie = plt.subplot(1, 2, 1)
ax_pie.pie(data.sentiment.value_counts(), labels=data.sentiment.value_counts().index, autopct='%1.1f%%', startangle=90)
ax_pie.set_title('Sentiment Distribution for Narendra Modi')

# Pie chart for bx
plt.subplot(1, 2, 2)
bx_pie = plt.subplot(1, 2, 2)
bx_pie.pie(data1.sentiment.value_counts(), labels=data1.sentiment.value_counts().index, autopct='%1.1f%%', startangle=90)
bx_pie.set_title('Sentiment Distribution for Rahul Gandhi')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Filter out neutral sentiment from data
data_without_neutral = data[data.sentiment != 'Neutral']
data1_without_neutral = data1[data1.sentiment != 'Neutral']

# Pie chart for ax without neutral sentiment
plt.figure(figsize=(10, 5))
ax_pie = plt.subplot(1, 2, 1)
ax_pie.pie(data_without_neutral.sentiment.value_counts(), labels=data_without_neutral.sentiment.value_counts().index, autopct='%1.1f%%', startangle=90)
ax_pie.set_title('Sentiment Analysis for Narendra Modi')

# Pie chart for bx without neutral sentiment
plt.subplot(1, 2, 2)
bx_pie = plt.subplot(1, 2, 2)
bx_pie.pie(data1_without_neutral.sentiment.value_counts(), labels=data1_without_neutral.sentiment.value_counts().index, autopct='%1.1f%%', startangle=90)
bx_pie.set_title('Sentiment Analysis for Rahul Gandhi')

plt.tight_layout()
plt.show()
